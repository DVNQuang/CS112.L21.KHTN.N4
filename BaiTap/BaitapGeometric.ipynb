# %% [markdown]
# <a href="https://colab.research.google.com/github/DVNQuang/CS112.L21.KHTN.N4/blob/main/BaiTap/BaitapGeometric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ĐỀ BÀI**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **GIẢI THUẬT**
#
# Chọn một điểm bất kì còn lại ngoài $k$ điểm tạo đa giác
# * Xét lần lượt từng cạnh thuộc đa giác:
#  * Nếu điểm khác phía với bất kì điểm nào còn lại ngoài 2 điểm tạo thành cạnh:
#     * Lập tức báo "No" và kết thúc.
#
#  * Nếu điểm cùng phía với các điểm còn lại ngoài 2 điểm tạo thành cạnh:
#     * Tiếp tục xét cạnh khác
#
# Sau khi duyệt hết cạnh $\rightarrow$ Đa giác đã cho là bao lồi của tập $n$ đỉnh
# * Trả về "Yes"
#
# #**ĐỘ PHỨC TẠP**
#
#
# Ta có độ phức tạp $O(kn)$
