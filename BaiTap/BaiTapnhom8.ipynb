# %% [markdown]
# <a href="https://colab.research.google.com/github/DVNQuang/CS112.L21.KHTN.N4/blob/main/BaiTap/BaiTapnhom8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Bài 1:
Chọn C. 

Bài 2: 
n + n/2 + n/4 + ... 1 => O(n) 

Bài 3:
T(n) =  T( sqrt(n)) + C1 với n > 2
 Cho n = 2^m,  T(n) = T(2^m)
   và T(2^m) =  S(m)

  Từ trên ta có T(n) = S(m)
Mà
  S(m) = S(m/2) + C1 (độ phức tạp của tìm kiếm nhị phân)
  S(m)  = O(logm)      
          = O(loglogn)  (vì n = 2^m )
  
  Quay lại độ phức tạp của hàm T(n) 
  T(n)  = S(m) 
          = O(LogLogn) 
Bài 4:

# %% [markdown]
# **Bài 1:**
# Độ phức tạp thời gian trong trường hợp xấu nhất luôn lớn hơn hoặc bằng độ phức tạp thời gian trung bình
#
# Chọn C/ $A(n)=O(W(n))$.
#
# **Bài 2:**
#
# $n + n/2 + n/4 + ... 1$ => $O(n) $
#
# **Bài 3:**
#
# $T(n) =  T( sqrt(n)) + C1$ với $n > 2$
#
#  $ n = 2^m,  T(n) = T(2^m)$ và $T(2^m) =  S(m)$
#
#   Từ trên ta có T(n) = S(m)
#
# Mà:
#
#   > $S(m) = S(m/2) + C1$ (độ phức tạp của tìm kiếm nhị phân)
#   > $S(m)  = O(logm)     = O(loglogn)$  (vì $n = 2^m$ )
#
#   Quay lại độ phức tạp của hàm $T(n)$
#   > $T(n)  = S(m) = O(LogLogn)$
#
# **Bài 4:**
#
# ![image.png](data:image/png;base64,...)
